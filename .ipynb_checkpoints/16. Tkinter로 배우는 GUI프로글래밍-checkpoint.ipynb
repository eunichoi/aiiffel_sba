# %% [markdown]
# # 16-4.

# %%
#tkinter 모듈 실행시키기_test
from tkinter import * #tkinter모듈 임포트

print('코드 실행 중..🛸')
window = Tk() #tk클래스의 인스턴스를 생성하고 변수명을 window로 설정
window.title("My First GUI") #title메소드 이용해 window인스턴스에 제목
window.mainloop() #mainloop메서드를 호출해 window의 이벤트 루프 시작
print('완료!')
# Out:
# 코드 실행 중..🛸
# 완료!

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 16-5. tkinter로 위젯만들기_size/label

# %%
from tkinter import *

print('코드 실행 중..🛸')
window = Tk()
window.title("ex1_size")              # 윈도우 타이틀바 제목을 지정합니다.

# 윈도우 크기 조정
window.geometry("480x320")   # 창의 크기를 지정합니다.
window.resizable(False, False)   # 가로, 세로 크기조절을 불가능하게 합니다.

window.mainloop()
print('완료!')
# Out:
# 코드 실행 중..🛸
# 완료!

# %%
#label == ui에 출력되는 고정텍스트
from tkinter import *
import tkinter.ttk as ttk

print('코드 실행 중..🛸')
window = Tk()
window.title("ex2_label")
window.geometry("480x320") 
window.resizable(False, False)

# 라벨 생성
label1 = ttk.Label(window,text='label')    # 라벨을 생성합니다. 텍스트 내용은 'label'로 합니다.
label1.grid(column=0, row=0)    # 위 생성된 라벨의 레이아웃을 지정합니다.

window.mainloop()
print('완료!')
# Out:
# 코드 실행 중..🛸
# 완료!

# %% [markdown]
# # 16-5. tkinter 라이브러리 탐구

# %% [markdown]
# 서 예제에서 size 는 tkinter 모듈에서 불러왔고 라벨은 tkinter의 ttk 모듈에서 불러왔습니다. 뭔가 좀 혼란스럽군요.
#
# 여기서는 tkinter 라이브러리에 대해서 잠깐 살펴보겠습니다.
#
# tkinter 는 파이썬 표준 라이브러리라고 했습니다. 파이썬은 표준 라이브러리는 lib 안에 설치되어 있을 것입니다. 직접 확인해 보겠습니다.
#
# tkinter 모듈이 설치되어 있는 곳으로 한번 가볼까요? 저는 처음 파이썬 설치 경로인 /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7 에서 확인할 수 있었는데요.
#
# 모듈 위치가 헷갈리시는 분, 즉 import 했을 때 현재 어느 위치에서 모듈을 가져오는지 궁금하다면 sys.path 를 통해 확인이 가능합니다.

# %%
import sys
sys.path
# Out:
# ['/home/choi/workplace',
#  '/home/choi/anaconda3/lib/python37.zip',
#  '/home/choi/anaconda3/lib/python3.7',
#  '/home/choi/anaconda3/lib/python3.7/lib-dynload',
#  '',
#  '/home/choi/anaconda3/lib/python3.7/site-packages',
#  '/home/choi/anaconda3/lib/python3.7/site-packages/IPython/extensions',
#  '/home/choi/.ipython']

# %%
from tkinter import *
import tkinter.ttk as ttk

print('코드 실행 중..🛸')
window = Tk()
window.title("ex2_label")
window.geometry("480x320") 
window.resizable(False, False)

label1 = ttk.Label(window,text='label')  
label1.grid(row=0, column=0)  

# 텍스트 박스 생성
text1 = Text(window, width=60, height=40)    # 텍스트박스를 크기까지 지정하여 생성합니다.
text1.grid(row=1, column=0, padx=20, pady=10)   # 생성된 텍스트박스의 레이아웃을 지정합니다. 

window.mainloop()
print('완료!')
# Out:
# 코드 실행 중..🛸
# 완료!

# %% [markdown]
# 라벨에 기입할 텍스트는 text 키워드 인자를 이용해 입력하고, 라벨이 기입될 윈도우인 window(Tk()에 의해 생성된)를 인자로 받습니다. 이것은 텍스트박스의 경우도 마찬가지입니다. 그리고 window.mainloop() 를 이용해 GUI를 실행하면 위와 같은 화면이 나오게 됩니다.
#
# 레이아웃 관련 메소드인 .grid()를 한번 눈여겨 봅시다. label1에는 row=0을, text1에는 row=1을 지정하였습니다. 그 결과 텍스트박스가 라벨 아래쪽에 위치하게 된다는 것을 알 수 있습니다.

# %%
from tkinter import *
import tkinter.ttk as ttk
import tkinter.messagebox as tmb

print('코드 실행 중..🛸')
window = Tk()   
window.title("ex3_Button")   
window.geometry("480x320") 

label1 = ttk.Label(window, text="Label")
label1.grid(column=0, row=0)

# 버튼클릭 이벤트 핸들러 정의
def click():
    label1.configure(text='버튼이 눌렸습니다.')   # 버튼이 눌리면 라벨 텍스트값을 바꿉니다.
    tmb.showinfo("버튼", "버튼클릭!!")                 # 그리고 메시지박스로 버튼클릭을 알립니다.

# 버튼 생성
action = ttk.Button(window, text="버튼을 눌러주세요", command=click)   
action.grid(row=0, column=1)

window.mainloop()
print('완료!')
# Out:
# 코드 실행 중..🛸
# 완료!

# %% [markdown]
# 이상으로 7가지 기본 위젯들에 대해 살펴봤는데요. 우리가 일반적으로 사용하는 GUI 화면에는 더 많은 버튼이 있죠? 위젯들의 종류는 스크롤바, 캔버스, 메뉴 등… 정말 다양합니다. 그 중 콤보박스를 하나 더 추가해 보겠습니다. 이번에는 버튼을 클릭했을 때, 콤보박스에 선택된 메뉴를 메시지박스로 출력해 보겠습니다.

# %%
from tkinter import *
import tkinter.ttk as ttk
import tkinter.messagebox as tmb

print('코드 실행 중..🛸')
window = Tk()   
window.title("ex3_Button")   
window.geometry("480x320") 

label1 = ttk.Label(window, text="Label")
label1.grid(column=0, row=0)

# 콤보 생성
combo = ttk.Combobox(window, width=10)
combo['values']= ("A", "B", "C")
combo.current(0) #set the selected item
combo.grid(row=100, column=700)

# 버튼클릭 이벤트 핸들러 정의
def click():
    label1.configure(text='버튼이 눌렸습니다.')   # 버튼이 눌리면 라벨 텍스트값을 바꿉니다.
    tmb.showinfo("버튼", combo.get())                # 메시지박스로 combo.get()을 통해 가져온 메뉴값을 출력합니다.

# 버튼 생성
action = ttk.Button(window, text="버튼을 눌러주세요", command=click)   
action.grid(row=0, column=1)

window.mainloop()
print('완료!')
# Out:
# 코드 실행 중..🛸
# 완료!

# %% [markdown]
# 이전 스텝에 만들어 보았던 텍스트 박스를 가져와 보겠습니다. 이번에는 버튼을 클릭할 경우 콤보 박스 메뉴와 텍스트 박스에 있던 내용을 합쳐서 다시 다른 텍스트 박스에 반영해 보겠습니다.

# %%
from tkinter import *
import tkinter.ttk as ttk

print('코드 실행 중..🛸')
window = Tk()   
window.title("ex3_Button")   
window.geometry("1024x512")     # 윈도우 크기를 좀더 키웁시다.

label1 = ttk.Label(window, text="Label")
label1.grid(column=0, row=0)

combo = ttk.Combobox(window, width=10)
combo['values']= ("A", "B", "C")
combo.current(0) #set the selected item
combo.grid(row=1, column=1)

# 텍스트 박스 2개 생성
text1 = Text(window, width=60, height=40)
text2 = Text(window, width=60, height=40)
text1.grid(row=2, column=0, padx=20, pady=10)   
text2.grid(row=2, column=1, padx=20, pady=10)

# 버튼클릭 이벤트 핸들러 정의
def click():
    label1.configure(text='버튼이 눌렸습니다.')   
    text1_string = text1.get("1.0","end")   # text1의 텍스트값을 가져와서
    text2_string = "{} and {}".format(text1_string, combo.get()) # text2에 들어갈 텍스트값을 생성한 후
    text2.delete(1.0, "end")     # text2의 텍스트값을 초기화하고 나서 
    text2.insert("end", text2_string)   # text2에 새로 생성한 텍스트를 넣어줍니다.  

action = ttk.Button(window, text="버튼을 눌러주세요", command=click)   
action.grid(row=0, column=1)

window.mainloop()
print('완료!')
# Out:
# 코드 실행 중..🛸
# 완료!

# %% [markdown]
# # 16-7.layout

# %% [markdown]
# Layout 관련 메소드는 다음과 같습니다.
#
#     .grid()
#     .pack()
#     .place()

# %% [markdown]
# 1.grid
# grid는 메인 윈도우를 격자 모양으로 나누었을 때의 row와 column 위치에 현재 위젯을 배치하겠다는 의미로 사용됩니다. 아래 코드에서 row 0, 1과 column 0, 1이 각각 어떻게 배치되었는지 확인해 보세요.

# %%
from tkinter import *
import tkinter.ttk as ttk

print('코드 실행 중..🛸')
window = Tk()
window.title("Layout")
window.geometry("480x320") 

Label(window, text="First").grid(row=0)      # row=0, column=0
Label(window, text="Second").grid(row=1)  # row=1, column=0

entry1 = Entry(window)
entry2 = Entry(window)

entry1.grid(row=0, column=1)    # row=0, column=1
entry2.grid(row=1, column=1)    # row=1, column=1
window.mainloop()
print('완료!')
# Out:
# 코드 실행 중..🛸
# 완료!

# %% [markdown]
# 각각의 라벨과 텍스트 상자의 위치를 확인해 보세요. window 의 빈 화면을 셀이라고 하고, 각 라벨과 텍스트 상자의 크기는 기본값으로 지정됩니다. grid 메소드 안의 인자값에 column, row 의 좌표로 각 위젯의 위치를 지정합니다.
# grid 메소드의 인자
#
#     column: 위젯을 넣을 열
#     columnspan : 위젯이 차지하는 열의 수 (열방향으로 병합하는 셀의 갯수)
#     row : 위젯을 넣을 행
#     rowspan : 위젯이 차지하는 행의 수(행방향으로 병합하는 셀의 갯수)
#     sticky, ipadx, ipady, padx, pady 로 위치와 여백을 조정할 수 있습니다.

# %% [markdown]
# 2. pack

# %%
from tkinter import *
import tkinter.ttk as ttk

print('코드 실행 중..🛸')
window = Tk()
window.title("Layout_pack")
window.geometry("480x320") 

Label(window, text="First").pack()
Label(window, text="Second").pack()

entry1 = Entry(window)
entry2 = Entry(window)
entry1.pack()
entry2.pack()

window.mainloop()
print('완료!')
# Out:
# 코드 실행 중..🛸
# 완료!

# %% [markdown]
# pack 은 조금 다른데요. 일단 정중앙에 위치시킵니다.
#
#     pack(side='left') : 왼쪽에 위치
#     pack(side='right') : 오른쪽에 위치
#     pack(side='top') : 위쪽에 위치
#     pack(side='bottom') : 아래쪽에 위치

# %%
from tkinter import *
import tkinter.ttk as ttk

print('코드 실행 중..🛸')
window = Tk()
window.title("Layout_pack")
window.geometry("480x320") 

B1 = Button(window, text="Left").pack(side="left")
B2 = Button(window, text="Right").pack(side="right")
B3 = Button(window, text="Top").pack(side="top")
B4 = Button(window, text="Bottom").pack(side="bottom")

window.mainloop()
print('완료!')
# Out:
# 코드 실행 중..🛸
# 완료!

# %%
from tkinter import *
import tkinter.ttk as ttk

print('코드 실행 중..🛸')
window = Tk()
window.title("Layout_pack")
window.geometry("480x320") 

B1 = Button(window, text="Left").pack(side="left", padx=20, pady=20)
B2 = Button(window, text="Right").pack(side="right", padx=20, pady=20)
B3 = Button(window, text="Top").pack(side="top", padx=20, pady=20)
B4 = Button(window, text="Bottom").pack(side="bottom", padx=20, pady=20)

window.mainloop()
print('완료!')
# Out:
# 코드 실행 중..🛸
# 완료!

# %% [markdown]
# 3.place

# %%
from tkinter import *
import tkinter.ttk as ttk

print('코드 실행 중..🛸')
window = Tk()
window.title("Layout_place")
window.geometry("480x320") 

Label(window, text="First").place(x=10,y=50)
Label(window, text="Second").place(x=10,y=80)

e1 = Entry(window)
e2 = Entry(window)
e1.place(x=80,y=50)
e2.place(x=80,y=80)

window.mainloop()
print('완료!')
# Out:
# 코드 실행 중..🛸
# 완료!

# %% [markdown]
#     x, y 인자를 이용해서 각각 수평 방향 및 수직 방향으로 얼마나 떨어지는지(offset 되어있는지)를 값으로 입력합니다.
#     그 밖에 anchor, bordermode, height, width, relheight, relwidth, relx, rely 와 같은 인자들로 위젯의 크기와 여백을 조정할 수 있습니다.

# %% [markdown]
# # 16-8. 나만의 구글번역기만들기

# %% [markdown]
#     목표

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 리눅스로 구글번역기 설치
#        $ pip install googletrans

# %%
from googletrans import Translator

def translate(input_str, lang='en'):
    translator = Translator()
    result = translator.translate(input_str, dest=lang)
    return result.text

translate('안녕하세요', lang='en')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-a80c256b1967> in <module>
#       6     return result.text
#       7
# ----> 8 translate('안녕하세요', lang='en')
#
# <ipython-input-17-a80c256b1967> in translate(input_str, lang)
#       3 def translate(input_str, lang='en'):
#       4     translator = Translator()
# ----> 5     result = translator.translate(input_str, dest=lang)
#       6     return result.text
#       7
#
# ~/anaconda3/lib/python3.7/site-packages/googletrans/client.py in translate(self, text, dest, src, **kwargs)
#     180
#     181         origin = text
# --> 182         data = self._translate(text, dest, src, kwargs)
#     183
#     184         # this code will be updated when the format is changed.
#
# ~/anaconda3/lib/python3.7/site-packages/googletrans/client.py in _translate(self, text, dest, src, override)
#      76
#      77     def _translate(self, text, dest, src, override):
# ---> 78         token = self.token_acquirer.do(text)
#      79         params = utils.build_params(query=text, src=src, dest=dest,
#      80                                     token=token, override=override)
#
# ~/anaconda3/lib/python3.7/site-packages/googletrans/gtoken.py in do(self, text)
#     192
#     193     def do(self, text):
# --> 194         self._update()
#     195         tk = self.acquire(text)
#     196         return tk
#
# ~/anaconda3/lib/python3.7/site-packages/googletrans/gtoken.py in _update(self)
#      60
#      61         # this will be the same as python code after stripping out a reserved word 'var'
# ---> 62         code = self.RE_TKK.search(r.text).group(1).replace('var ', '')
#      63         # unescape special ascii characters such like a \x3d(=)
#      64         code = code.encode().decode('unicode-escape')
#
# AttributeError: 'NoneType' object has no attribute 'group'

# %%
from tkinter import *
import tkinter.ttk as ttk
from googletrans import Translator

print('코드 실행 중..🛸')
window = Tk()
window.title("나의 구글 번역기")
window.geometry("1024x512")

# 라벨 생성
# [[YOUR CODE]]

# 콤보박스 생성
# [[YOUR CODE]]

# 텍스트 박스 생성
# [[YOUR CODE]]

# 번역기 함수
def translate(input_str, lang='en'):
    translator = Translator()
    result = translator.translate(input_str, dest=lang)
    return result.text

# 버튼클릭 콜백 함수    
# [[YOUR CODE]]

# 버튼 생성    
# [[YOUR CODE]]

window.mainloop()
print('완료!')
# Out:
# 코드 실행 중..🛸
# 완료!

# %%
#정답
from tkinter import *
import tkinter.ttk as ttk
from googletrans import Translator

print('코드 실행 중..🛸')
window = Tk()
window.title("나의 구글 번역기")

window.geometry("1024x512")

label1 = Label(window, text="번역전")
label2 = Label(window, text="번역후")
label1.grid(row=0, column=0, padx=20, pady=10)
label2.grid(row=0, column=2, padx=20, pady=10)

combo = ttk.Combobox(window, width=10)
combo['values']= ("en", "ko", "ja")
combo.current(0) #set the selected item
combo.grid(row=0, column=1)

text1 = Text(window, width=60, height=40)
text2 = Text(window, width=60, height=40)
text1.grid(row=1, column=0, padx=20, pady=10)
text2.grid(row=1, column=2, padx=20, pady=10)


def translate(input_str, lang='en'):
    translator = Translator()
    result = translator.translate(input_str, dest=lang)
    return result.text

def click():
    intput_str = text1.get("1.0","end")
    lang=combo.get()
    output_str = translate(intput_str, lang=lang)
    text2.delete(1.0, "end")
    text2.insert("end", output_str)

action = ttk.Button(window, text="번역", command=click)   
action.grid(row=1, column=1)

window.mainloop()
print('완료!')
# Out:
# 코드 실행 중..🛸
# 완료!
